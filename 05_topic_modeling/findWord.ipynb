# %%
import pandas as pd

df = pd.read_json('data/split_by_category/Bodycare.json', lines=True)
# ตัวอย่าง DataFrame
data = {
    'tag': ['Packing', 'Packing', 'Packaging', 'Packing', 'Quality'],
    'text': ['quickly delivered', 'arrived fast', 'box damaged', 'very quickly packed', 'smells nice']
}
df = pd.DataFrame(data)

# เลือกเฉพาะแถวที่ tag เป็น "Packing" และมีคำว่า "quickly" ในคอลัมน์ text
result = df[(df['tag'] == 'Packing') & (df['text'].str.contains('quickly', case=False, na=False))]

print(df.head())  # ดู 5 แถวแรก
print(df.columns)  # ดูชื่อคอลัมน์ทั้งหมด
